# %%
# %%capture
import matplotlib.pyplot as plt

from IPython import display

from torch.optim.lr_scheduler import StepLR
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
from tqdm.notebook import tqdm

# %matplotlib inline

# %%
seed = 543 # Do not change this

def fix(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# %%capture
import gym
import random
seed = 543
fix(seed)
env = gym.make('LunarLander-v2')

# %%
print(env.observation_space)
# Out:
# Box([-1.5       -1.5       -5.        -5.        -3.1415927 -5.
#  -0.        -0.       ], [1.5       1.5       5.        5.        3.1415927 5.        1.
#  1.       ], (8,), float32)

# %%
print(env.action_space)
# Out:
# Discrete(4)

# %%
initial_state = env.reset()
print(initial_state)
# Out:
# (array([-0.00566216,  1.4077348 , -0.5735394 , -0.14158951,  0.00656792,
#         0.12991525,  0.        ,  0.        ], dtype=float32), {})

# %%
random_action = env.action_space.sample()
print(random_action)
observation, reward, done, info, _ = env.step(random_action)
# Out:
# 0

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.net1 = nn.Sequential(
            nn.Linear(8,32),
            nn.Tanh(),
            nn.Linear(32,32),
        )
        self.net2 = nn.Sequential(
            nn.Linear(32,16),
            nn.ReLU(),
            nn.Linear(16,4),
        )

    def forward(self, state):
        hid = torch.tanh(self.net1(state))
        return F.softmax(self.net2(hid), dim=-1), hid
    
class RewardNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(32,16),
            nn.Tanh(),
            nn.Linear(16,1)
        )

    def forward(self, hid):
        return self.net(hid)

# %%
class PolicyGradientAgent():
    
    def __init__(self, network, rewardnet, epoch):
        self.network = network
        self.optimizerN = optim.SGD(self.network.parameters(), lr=0.001)
        torch.nn.utils.clip_grad_norm_(self.network.parameters(), 1)
        self.rewardnet = rewardnet
        self.optimizerR = optim.SGD(self.rewardnet.parameters(), lr=0.001)
        torch.nn.utils.clip_grad_norm_(self.rewardnet.parameters(), 1)
        self.loss_a = []
        self.loss_r = []
         
    def forward(self, state, Act=True):
        action, hid = self.network(state)
        reward = self.rewardnet(hid.detach())
        return action, hid, reward
        
    def learn(self, log_probs, rewards, pd_rewards, pd_rewards1, epoch):
        At = rewards + pd_rewards1 - pd_rewards
        loss = (-log_probs * At).sum()
        self.loss_a.append(loss.item())        
        self.optimizerN.zero_grad()
        loss.backward(retain_graph=True)
        self.optimizerN.step()

        reward_loss = torch.nn.MSELoss()(rewards.clone(), pd_rewards.clone())
        self.loss_r.append(reward_loss.item())
        self.optimizerR.zero_grad()
        reward_loss.backward()
        self.optimizerR.step()
        
            
        
    def sample(self, state):
        action_prob, _, reward = self.forward(torch.FloatTensor(state))
        action_dist = Categorical(action_prob)
        action = action_dist.sample()
        log_prob = action_dist.log_prob(action)
        return action.item(), log_prob, reward

# %%
EPISODE_PER_BATCH = 5  # 每蒐集 5 個 episodes 更新一次 agent
NUM_BATCH = 1000        # 總共更新 400 次
lamb = 0.99

network = Network()
reward_net = RewardNet()
agent = PolicyGradientAgent(network,reward_net,NUM_BATCH)
agent.network.train()
agent.rewardnet.train()

avg_total_rewards, avg_final_rewards = [], []

# %%
prg_bar = tqdm(range(NUM_BATCH))
best = 0
for batch in prg_bar:

    log_probs, rewards, pd_rewards, pd_rewards1 = [], [], [], []
    total_rewards, final_rewards = [], []
    
    # 蒐集訓練資料
    for episode in range(EPISODE_PER_BATCH):
        
        state = env.reset()[0]
        total_reward, total_step = 0, 0
        seq_rewards = []
        pd = []
        while True:
            action, log_prob, pd_reward = agent.sample(state) # at , log(at|st)
            
            next_state, reward, done, info, _= env.step(action)
            log_probs.append(log_prob) # [log(a1|s1), log(a2|s2), ...., log(at|st)]
            seq_rewards.append(reward)
            pd.append(pd_reward)
            total_step += 1
            
            state = next_state
            
            prg_bar.set_postfix({"current_step":total_step})
            if done or total_step == 2000:
                seq_rewards = np.array(seq_rewards)

                # 计算幂次项的数组
                l = len(seq_rewards)
                powers = np.power(lamb, np.arange(l))
                # 使用向量化操作计算reward_li
                reward_li = [np.sum(seq_rewards[i:]*powers[:l-i]) for i in range(l)]
                rewards += list(reward_li)
                pd_rewards += pd
                _, _, pd_reward1 = agent.sample(state)
                pd_rewards1 += pd[1:] + [pd_reward1]
                final_rewards.append(seq_rewards[-1])
                total_rewards.append(sum(seq_rewards))
                break

    print(f"rewards looks like ", np.shape(rewards))  
    print(f"log_probs looks like ", len(log_probs))     
    # 紀錄訓練過程
    avg_total_reward = sum(total_rewards) / len(total_rewards)
    avg_final_reward = sum(final_rewards) / len(final_rewards)
    avg_total_rewards.append(avg_total_reward)
    avg_final_rewards.append(avg_final_reward)
    prg_bar.set_description(f"Total: {avg_total_reward: 4.1f}, Final: {avg_final_reward: 4.1f}")
    if avg_total_reward > best:
        print("save_best:",batch)
        torch.save(network.state_dict(),"best_net.bin")
        torch.save(reward_net.state_dict(),"best_reward_net.bin")

    # 更新網路
    # rewards = np.concatenate(rewards, axis=0)
    rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-9)  # 將 reward 正規標準化
    agent.learn(torch.stack(log_probs), torch.from_numpy(rewards).float(), torch.cat(pd_rewards), torch.cat(pd_rewards1), NUM_BATCH)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# rewards looks like  (440,)
# log_probs looks like  440
# rewards looks like  (534,)
# log_probs looks like  534
# rewards looks like  (499,)
# log_probs looks like  499
# rewards looks like  (546,)
# log_probs looks like  546
# rewards looks like  (446,)
# log_probs looks like  446
# rewards looks like  (497,)
# log_probs looks like  497
# rewards looks like  (574,)
# log_probs looks like  574
# rewards looks like  (528,)
# log_probs looks like  528
# rewards looks like  (545,)
# log_probs looks like  545
# rewards looks like  (528,)
# log_probs looks like  528
# rewards looks like  (498,)
# log_probs looks like  498
# rewards looks like  (437,)
# log_probs looks like  437
# rewards looks like  (492,)
# log_probs looks like  492
# rewards looks like  (641,)
# log_probs looks like  641
# rewards looks like  (520,)
# log_probs looks like  520
# rewards looks like  (500,)
# log_probs looks like  500
# rewards looks like  (532,)
# log_probs looks like  532
# rewards looks like  (593,)
# log_probs looks like  593
# rewards looks like  (449,)
# log_probs looks like  449
# rewards looks like  (493,)
# log_probs looks like  493
# rewards looks like  (433,)
# log_probs looks like  433
# rewards looks like  (493,)
# log_probs looks like  493
# rewards looks like  (516,)
# log_probs looks like  516
# rewards looks like  (439,)
# log_probs looks like  439
# rewards looks like  (563,)
# log_probs looks like  563
# rewards looks like  (472,)
# log_probs looks like  472
# rewards looks like  (571,)
# log_probs looks like  571
# rewards looks like  (417,)
# log_probs looks like  417
# rewards looks like  (528,)
# log_probs looks like  528
# rewards looks like  (398,)
# log_probs looks like  398
# rewards looks like  (570,)
# log_probs looks like  570
# rewards looks like  (551,)
# log_probs looks like  551
# rewards looks like  (578,)
# log_probs looks like  578
# rewards looks like  (477,)
# log_probs looks like  477
# rewards looks like  (489,)
# log_probs looks like  489
# rewards looks like  (470,)
# log_probs looks like  470
# rewards looks like  (536,)
# log_probs looks like  536
# rewards looks like  (469,)
# log_probs looks like  469
# rewards looks like  (618,)
# log_probs looks like  618
# rewards looks like  (517,)
# log_probs looks like  517
# rewards looks like  (489,)
# log_probs looks like  489
# rewards looks like  (515,)
# log_probs looks like  515
# rewards looks like  (513,)
# log_probs looks like  513
# rewards looks like  (497,)
# log_probs looks like  497
# rewards looks like  (554,)
# log_probs looks like  554
# rewards looks like  (531,)
# log_probs looks like  531
# rewards looks like  (403,)
# log_probs looks like  403
# rewards looks like  (536,)
# log_probs looks like  536
# rewards looks like  (479,)
# log_probs looks like  479
# rewards looks like  (580,)
# log_probs looks like  580
# rewards looks like  (409,)
# log_probs looks like  409
# rewards looks like  (480,)
# log_probs looks like  480
# rewards looks like  (445,)
# log_probs looks like  445
# rewards looks like  (464,)
# log_probs looks like  464
# rewards looks like  (528,)
# log_probs looks like  528
# rewards looks like  (470,)
# log_probs looks like  470
# rewards looks like  (492,)
# log_probs looks like  492
# rewards looks like  (500,)
# log_probs looks like  500
# rewards looks like  (461,)
# log_probs looks like  461
# rewards looks like  (483,)
# log_probs looks like  483
# rewards looks like  (517,)
# log_probs looks like  517
# rewards looks like  (546,)
# log_probs looks like  546
# rewards looks like  (531,)
# log_probs looks like  531
# rewards looks like  (545,)
# log_probs looks like  545
# rewards looks like  (534,)
# log_probs looks like  534
# rewards looks like  (472,)
# log_probs looks like  472
# rewards looks like  (467,)
# log_probs looks like  467
# rewards looks like  (415,)
# log_probs looks like  415
# rewards looks like  (513,)
# log_probs looks like  513
# rewards looks like  (535,)
# log_probs looks like  535
# rewards looks like  (482,)
# log_probs looks like  482
# rewards looks like  (426,)
# log_probs looks like  426
# rewards looks like  (430,)
# log_probs looks like  430
# rewards looks like  (554,)
# log_probs looks like  554
# rewards looks like  (467,)
# log_probs looks like  467
# rewards looks like  (435,)
# log_probs looks like  435
# rewards looks like  (532,)
# log_probs looks like  532
# rewards looks like  (421,)
# log_probs looks like  421
# rewards looks like  (465,)
# log_probs looks like  465
# rewards looks like  (503,)
# log_probs looks like  503
# rewards looks like  (484,)
# log_probs looks like  484
# rewards looks like  (566,)
# log_probs looks like  566
# rewards looks like  (537,)
# log_probs looks like  537
# rewards looks like  (474,)
# log_probs looks like  474
# rewards looks like  (456,)
# log_probs looks like  456
# rewards looks like  (389,)
# log_probs looks like  389
# rewards looks like  (538,)
# log_probs looks like  538
# rewards looks like  (589,)
# log_probs looks like  589
# rewards looks like  (463,)
# log_probs looks like  463
# rewards looks like  (536,)
# log_probs looks like  536
# rewards looks like  (512,)
# log_probs looks like  512
# rewards looks like  (510,)
# log_probs looks like  510
# rewards looks like  (418,)
# log_probs looks like  418
# rewards looks like  (447,)
# log_probs looks like  447
# rewards looks like  (542,)
# log_probs looks like  542
# rewards looks like  (499,)
# log_probs looks like  499
# rewards looks like  (434,)
# log_probs looks like  434
# rewards looks like  (596,)
# log_probs looks like  596
# rewards looks like  (550,)
# log_probs looks like  550
# rewards looks like  (583,)
# log_probs looks like  583
# rewards looks like  (398,)
# log_probs looks like  398
# rewards looks like  (522,)
# log_probs looks like  522
# rewards looks like  (581,)
# log_probs looks like  581
# rewards looks like  (408,)
# log_probs looks like  408
# rewards looks like  (553,)
# log_probs looks like  553
# rewards looks like  (490,)
# log_probs looks like  490
# rewards looks like  (441,)
# log_probs looks like  441
# rewards looks like  (487,)
# log_probs looks like  487
# rewards looks like  (576,)
# log_probs looks like  576
# rewards looks like  (541,)
# log_probs looks like  541
# rewards looks like  (584,)
# log_probs looks like  584
# rewards looks like  (499,)
# log_probs looks like  499
# rewards looks like  (560,)
# log_probs looks like  560
# rewards looks like  (490,)
# log_probs looks like  490
# rewards looks like  (490,)
# log_probs looks like  490
# rewards looks like  (500,)
# log_probs looks like  500
# rewards looks like  (542,)
# log_probs looks like  542
# rewards looks like  (502,)
# log_probs looks like  502
# rewards looks like  (513,)
# log_probs looks like  513
# rewards looks like  (462,)
# log_probs looks like  462
# rewards looks like  (499,)
# log_probs looks like  499
# rewards looks like  (464,)
# log_probs looks like  464
# rewards looks like  (403,)
# log_probs looks like  403
# rewards looks like  (522,)
# log_probs looks like  522
# rewards looks like  (519,)
# log_probs looks like  519
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (487,)
# log_probs looks like  487
# rewards looks like  (485,)
# log_probs looks like  485
# rewards looks like  (525,)
# log_probs looks like  525
# rewards looks like  (557,)
# log_probs looks like  557
# rewards looks like  (512,)
# log_probs looks like  512
# rewards looks like  (472,)
# log_probs looks like  472
# rewards looks like  (504,)
# log_probs looks like  504
# rewards looks like  (463,)
# log_probs looks like  463
# rewards looks like  (502,)
# log_probs looks like  502
# rewards looks like  (501,)
# log_probs looks like  501
# rewards looks like  (473,)
# log_probs looks like  473
# rewards looks like  (497,)
# log_probs looks like  497
# rewards looks like  (367,)
# log_probs looks like  367
# rewards looks like  (476,)
# log_probs looks like  476
# rewards looks like  (549,)
# log_probs looks like  549
# rewards looks like  (387,)
# log_probs looks like  387
# rewards looks like  (583,)
# log_probs looks like  583
# rewards looks like  (536,)
# log_probs looks like  536
# rewards looks like  (423,)
# log_probs looks like  423
# rewards looks like  (621,)
# log_probs looks like  621
# rewards looks like  (574,)
# log_probs looks like  574
# rewards looks like  (486,)
# log_probs looks like  486
# rewards looks like  (525,)
# log_probs looks like  525
# rewards looks like  (487,)
# log_probs looks like  487
# rewards looks like  (499,)
# log_probs looks like  499
# rewards looks like  (469,)
# log_probs looks like  469
# rewards looks like  (534,)
# log_probs looks like  534
# rewards looks like  (493,)
# log_probs looks like  493
# rewards looks like  (498,)
# log_probs looks like  498
# rewards looks like  (459,)
# log_probs looks like  459
# rewards looks like  (476,)
# log_probs looks like  476
# rewards looks like  (568,)
# log_probs looks like  568
# rewards looks like  (486,)
# log_probs looks like  486
# rewards looks like  (468,)
# log_probs looks like  468
# rewards looks like  (494,)
# log_probs looks like  494
# rewards looks like  (540,)
# log_probs looks like  540
# rewards looks like  (662,)
# log_probs looks like  662
# rewards looks like  (436,)
# log_probs looks like  436
# rewards looks like  (495,)
# log_probs looks like  495
# rewards looks like  (454,)
# log_probs looks like  454
# rewards looks like  (395,)
# log_probs looks like  395
# rewards looks like  (497,)
# log_probs looks like  497
# rewards looks like  (484,)
# log_probs looks like  484
# rewards looks like  (399,)
# log_probs looks like  399
# rewards looks like  (425,)
# log_probs looks like  425
# rewards looks like  (445,)
# log_probs looks like  445
# rewards looks like  (405,)
# log_probs looks like  405
# rewards looks like  (525,)
# log_probs looks like  525
# rewards looks like  (480,)
# log_probs looks like  480
# rewards looks like  (486,)
# log_probs looks like  486
# rewards looks like  (519,)
# log_probs looks like  519
# rewards looks like  (479,)
# log_probs looks like  479
# rewards looks like  (526,)
# log_probs looks like  526
# rewards looks like  (578,)
# log_probs looks like  578
# rewards looks like  (453,)
# log_probs looks like  453
# rewards looks like  (535,)
# log_probs looks like  535
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (603,)
# log_probs looks like  603
# rewards looks like  (466,)
# log_probs looks like  466
# rewards looks like  (527,)
# log_probs looks like  527
# rewards looks like  (441,)
# log_probs looks like  441
# rewards looks like  (599,)
# log_probs looks like  599
# rewards looks like  (483,)
# log_probs looks like  483
# rewards looks like  (517,)
# log_probs looks like  517
# rewards looks like  (556,)
# log_probs looks like  556
# rewards looks like  (440,)
# log_probs looks like  440
# rewards looks like  (489,)
# log_probs looks like  489
# rewards looks like  (448,)
# log_probs looks like  448
# rewards looks like  (468,)
# log_probs looks like  468
# rewards looks like  (417,)
# log_probs looks like  417
# rewards looks like  (554,)
# log_probs looks like  554
# rewards looks like  (499,)
# log_probs looks like  499
# rewards looks like  (422,)
# log_probs looks like  422
# rewards looks like  (427,)
# log_probs looks like  427
# rewards looks like  (487,)
# log_probs looks like  487
# rewards looks like  (503,)
# log_probs looks like  503
# rewards looks like  (424,)
# log_probs looks like  424
# rewards looks like  (455,)
# log_probs looks like  455
# rewards looks like  (514,)
# log_probs looks like  514
# rewards looks like  (452,)
# log_probs looks like  452
# rewards looks like  (419,)
# log_probs looks like  419
# rewards looks like  (420,)
# log_probs looks like  420
# rewards looks like  (468,)
# log_probs looks like  468
# rewards looks like  (2440,)
# log_probs looks like  2440
# rewards looks like  (473,)
# log_probs looks like  473
# rewards looks like  (534,)
# log_probs looks like  534
# rewards looks like  (474,)
# log_probs looks like  474
# rewards looks like  (535,)
# log_probs looks like  535
# rewards looks like  (587,)
# log_probs looks like  587
# rewards looks like  (538,)
# log_probs looks like  538
# rewards looks like  (554,)
# log_probs looks like  554
# rewards looks like  (557,)
# log_probs looks like  557
# rewards looks like  (544,)
# log_probs looks like  544
# rewards looks like  (541,)
# log_probs looks like  541
# rewards looks like  (591,)
# log_probs looks like  591
# rewards looks like  (471,)
# log_probs looks like  471
# rewards looks like  (526,)
# log_probs looks like  526
# rewards looks like  (550,)
# log_probs looks like  550
# rewards looks like  (501,)
# log_probs looks like  501
# rewards looks like  (573,)
# log_probs looks like  573
# rewards looks like  (475,)
# log_probs looks like  475
# rewards looks like  (488,)
# log_probs looks like  488
# rewards looks like  (507,)
# log_probs looks like  507
# rewards looks like  (485,)
# log_probs looks like  485
# rewards looks like  (614,)
# log_probs looks like  614
# rewards looks like  (474,)
# log_probs looks like  474
# rewards looks like  (507,)
# log_probs looks like  507
# rewards looks like  (495,)
# log_probs looks like  495
# rewards looks like  (516,)
# log_probs looks like  516
# rewards looks like  (505,)
# log_probs looks like  505
# rewards looks like  (461,)
# log_probs looks like  461
# rewards looks like  (550,)
# log_probs looks like  550
# rewards looks like  (527,)
# log_probs looks like  527
# rewards looks like  (503,)
# log_probs looks like  503
# rewards looks like  (474,)
# log_probs looks like  474
# rewards looks like  (469,)
# log_probs looks like  469
# rewards looks like  (508,)
# log_probs looks like  508
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (490,)
# log_probs looks like  490
# rewards looks like  (576,)
# log_probs looks like  576
# rewards looks like  (558,)
# log_probs looks like  558
# rewards looks like  (420,)
# log_probs looks like  420
# rewards looks like  (515,)
# log_probs looks like  515
# rewards looks like  (627,)
# log_probs looks like  627
# rewards looks like  (567,)
# log_probs looks like  567
# rewards looks like  (478,)
# log_probs looks like  478
# rewards looks like  (516,)
# log_probs looks like  516
# rewards looks like  (505,)
# log_probs looks like  505
# rewards looks like  (418,)
# log_probs looks like  418
# rewards looks like  (498,)
# log_probs looks like  498
# rewards looks like  (572,)
# log_probs looks like  572
# rewards looks like  (547,)
# log_probs looks like  547
# rewards looks like  (570,)
# log_probs looks like  570
# rewards looks like  (543,)
# log_probs looks like  543
# rewards looks like  (538,)
# log_probs looks like  538
# rewards looks like  (540,)
# log_probs looks like  540
# rewards looks like  (709,)
# log_probs looks like  709
# rewards looks like  (596,)
# log_probs looks like  596
# rewards looks like  (550,)
# log_probs looks like  550
# rewards looks like  (574,)
# log_probs looks like  574
# rewards looks like  (468,)
# log_probs looks like  468
# rewards looks like  (692,)
# log_probs looks like  692
# rewards looks like  (682,)
# log_probs looks like  682
# rewards looks like  (1840,)
# log_probs looks like  1840
# rewards looks like  (636,)
# log_probs looks like  636
# rewards looks like  (737,)
# log_probs looks like  737
# rewards looks like  (754,)
# log_probs looks like  754
# rewards looks like  (661,)
# log_probs looks like  661
# rewards looks like  (556,)
# log_probs looks like  556
# rewards looks like  (497,)
# log_probs looks like  497
# rewards looks like  (754,)
# log_probs looks like  754
# rewards looks like  (690,)
# log_probs looks like  690
# rewards looks like  (653,)
# log_probs looks like  653
# rewards looks like  (496,)
# log_probs looks like  496
# rewards looks like  (835,)
# log_probs looks like  835
# rewards looks like  (617,)
# log_probs looks like  617
# rewards looks like  (780,)
# log_probs looks like  780
# rewards looks like  (669,)
# log_probs looks like  669
# rewards looks like  (507,)
# log_probs looks like  507
# rewards looks like  (458,)
# log_probs looks like  458
# rewards looks like  (574,)
# log_probs looks like  574
# rewards looks like  (543,)
# log_probs looks like  543
# rewards looks like  (709,)
# log_probs looks like  709
# rewards looks like  (508,)
# log_probs looks like  508
# rewards looks like  (653,)
# log_probs looks like  653
# rewards looks like  (626,)
# log_probs looks like  626
# rewards looks like  (673,)
# log_probs looks like  673
# rewards looks like  (611,)
# log_probs looks like  611
# rewards looks like  (634,)
# log_probs looks like  634
# rewards looks like  (569,)
# log_probs looks like  569
# rewards looks like  (568,)
# log_probs looks like  568
# rewards looks like  (549,)
# log_probs looks like  549
# rewards looks like  (617,)
# log_probs looks like  617
# rewards looks like  (607,)
# log_probs looks like  607
# rewards looks like  (527,)
# log_probs looks like  527
# rewards looks like  (545,)
# log_probs looks like  545
# rewards looks like  (456,)
# log_probs looks like  456
# rewards looks like  (473,)
# log_probs looks like  473
# rewards looks like  (490,)
# log_probs looks like  490
# rewards looks like  (506,)
# log_probs looks like  506
# rewards looks like  (569,)
# log_probs looks like  569
# rewards looks like  (613,)
# log_probs looks like  613
# rewards looks like  (458,)
# log_probs looks like  458
# rewards looks like  (678,)
# log_probs looks like  678
# rewards looks like  (557,)
# log_probs looks like  557
# rewards looks like  (625,)
# log_probs looks like  625
# rewards looks like  (537,)
# log_probs looks like  537
# rewards looks like  (547,)
# log_probs looks like  547
# rewards looks like  (585,)
# log_probs looks like  585
# rewards looks like  (597,)
# log_probs looks like  597
# rewards looks like  (652,)
# log_probs looks like  652
# rewards looks like  (474,)
# log_probs looks like  474
# rewards looks like  (604,)
# log_probs looks like  604
# rewards looks like  (487,)
# log_probs looks like  487
# rewards looks like  (656,)
# log_probs looks like  656
# rewards looks like  (690,)
# log_probs looks like  690
# rewards looks like  (666,)
# log_probs looks like  666
# rewards looks like  (618,)
# log_probs looks like  618
# rewards looks like  (551,)
# log_probs looks like  551
# rewards looks like  (724,)
# log_probs looks like  724
# rewards looks like  (726,)
# log_probs looks like  726
# rewards looks like  (480,)
# log_probs looks like  480
# rewards looks like  (619,)
# log_probs looks like  619
# rewards looks like  (712,)
# log_probs looks like  712
# rewards looks like  (2519,)
# log_probs looks like  2519
# rewards looks like  (439,)
# log_probs looks like  439
# rewards looks like  (577,)
# log_probs looks like  577
# rewards looks like  (577,)
# log_probs looks like  577
# rewards looks like  (566,)
# log_probs looks like  566
# rewards looks like  (555,)
# log_probs looks like  555
# rewards looks like  (623,)
# log_probs looks like  623
# rewards looks like  (709,)
# log_probs looks like  709
# rewards looks like  (634,)
# log_probs looks like  634
# rewards looks like  (699,)
# log_probs looks like  699
# rewards looks like  (658,)
# log_probs looks like  658
# rewards looks like  (626,)
# log_probs looks like  626
# rewards looks like  (745,)
# log_probs looks like  745
# rewards looks like  (1146,)
# log_probs looks like  1146
# rewards looks like  (1025,)
# log_probs looks like  1025
# rewards looks like  (1180,)
# log_probs looks like  1180
# rewards looks like  (849,)
# log_probs looks like  849
# rewards looks like  (709,)
# log_probs looks like  709
# rewards looks like  (719,)
# log_probs looks like  719
# rewards looks like  (909,)
# log_probs looks like  909
# rewards looks like  (2196,)
# log_probs looks like  2196
# rewards looks like  (791,)
# log_probs looks like  791
# rewards looks like  (877,)
# log_probs looks like  877
# rewards looks like  (744,)
# log_probs looks like  744
# rewards looks like  (1282,)
# log_probs looks like  1282
# rewards looks like  (662,)
# log_probs looks like  662
# rewards looks like  (728,)
# log_probs looks like  728
# rewards looks like  (831,)
# log_probs looks like  831
# rewards looks like  (686,)
# log_probs looks like  686
# rewards looks like  (2373,)
# log_probs looks like  2373
# rewards looks like  (710,)
# log_probs looks like  710
# rewards looks like  (745,)
# log_probs looks like  745
# rewards looks like  (922,)
# log_probs looks like  922
# rewards looks like  (739,)
# log_probs looks like  739
# rewards looks like  (882,)
# log_probs looks like  882
# rewards looks like  (834,)
# log_probs looks like  834
# rewards looks like  (723,)
# log_probs looks like  723
# rewards looks like  (1143,)
# log_probs looks like  1143
# rewards looks like  (954,)
# log_probs looks like  954
# rewards looks like  (1016,)
# log_probs looks like  1016
# rewards looks like  (938,)
# log_probs looks like  938
# rewards looks like  (641,)
# log_probs looks like  641
# rewards looks like  (700,)
# log_probs looks like  700
# rewards looks like  (663,)
# log_probs looks like  663
# rewards looks like  (928,)
# log_probs looks like  928
# rewards looks like  (1660,)
# log_probs looks like  1660
# rewards looks like  (1152,)
# log_probs looks like  1152
# rewards looks like  (775,)
# log_probs looks like  775
# rewards looks like  (871,)
# log_probs looks like  871
# rewards looks like  (939,)
# log_probs looks like  939
# rewards looks like  (1094,)
# log_probs looks like  1094
# rewards looks like  (875,)
# log_probs looks like  875
# rewards looks like  (1006,)
# log_probs looks like  1006
# rewards looks like  (799,)
# log_probs looks like  799
# rewards looks like  (2202,)
# log_probs looks like  2202
# rewards looks like  (763,)
# log_probs looks like  763
# rewards looks like  (807,)
# log_probs looks like  807
# rewards looks like  (1018,)
# log_probs looks like  1018
# rewards looks like  (775,)
# log_probs looks like  775
# rewards looks like  (1022,)
# log_probs looks like  1022
# rewards looks like  (1002,)
# log_probs looks like  1002
# rewards looks like  (1333,)
# log_probs looks like  1333
# rewards looks like  (955,)
# log_probs looks like  955
# rewards looks like  (1956,)
# log_probs looks like  1956
# rewards looks like  (2046,)
# log_probs looks like  2046
# rewards looks like  (2243,)
# log_probs looks like  2243
# rewards looks like  (676,)
# log_probs looks like  676
# rewards looks like  (522,)
# log_probs looks like  522
# rewards looks like  (632,)
# log_probs looks like  632
# rewards looks like  (693,)
# log_probs looks like  693
# rewards looks like  (865,)
# log_probs looks like  865
# rewards looks like  (1760,)
# log_probs looks like  1760
# rewards looks like  (1071,)
# log_probs looks like  1071
# rewards looks like  (884,)
# log_probs looks like  884
# rewards looks like  (954,)
# log_probs looks like  954
# rewards looks like  (865,)
# log_probs looks like  865
# rewards looks like  (4359,)
# log_probs looks like  4359
# rewards looks like  (2209,)
# log_probs looks like  2209
# rewards looks like  (749,)
# log_probs looks like  749
# rewards looks like  (704,)
# log_probs looks like  704
# rewards looks like  (708,)
# log_probs looks like  708
# rewards looks like  (641,)
# log_probs looks like  641
# rewards looks like  (1242,)
# log_probs looks like  1242
# rewards looks like  (1507,)
# log_probs looks like  1507
# rewards looks like  (1891,)
# log_probs looks like  1891
# rewards looks like  (3435,)
# log_probs looks like  3435
# rewards looks like  (587,)
# log_probs looks like  587
# rewards looks like  (894,)
# log_probs looks like  894
# rewards looks like  (1430,)
# log_probs looks like  1430
# rewards looks like  (3347,)
# log_probs looks like  3347
# rewards looks like  (2994,)
# log_probs looks like  2994
# rewards looks like  (777,)
# log_probs looks like  777
# rewards looks like  (1399,)
# log_probs looks like  1399
# rewards looks like  (5263,)
# log_probs looks like  5263
# rewards looks like  (677,)
# log_probs looks like  677
# rewards looks like  (660,)
# log_probs looks like  660
# rewards looks like  (685,)
# log_probs looks like  685
# rewards looks like  (606,)
# log_probs looks like  606
# rewards looks like  (727,)
# log_probs looks like  727
# rewards looks like  (763,)
# log_probs looks like  763
# rewards looks like  (680,)
# log_probs looks like  680
# rewards looks like  (4817,)
# log_probs looks like  4817
# rewards looks like  (834,)
# log_probs looks like  834
# save_best: 432
# rewards looks like  (4160,)
# log_probs looks like  4160
# rewards looks like  (688,)
# log_probs looks like  688
# rewards looks like  (2668,)
# log_probs looks like  2668
# rewards looks like  (752,)
# log_probs looks like  752
# rewards looks like  (2508,)
# log_probs looks like  2508
# rewards looks like  (769,)
# log_probs looks like  769
# rewards looks like  (638,)
# log_probs looks like  638
# rewards looks like  (813,)
# log_probs looks like  813
# rewards looks like  (631,)
# log_probs looks like  631
# rewards looks like  (2532,)
# log_probs looks like  2532
# rewards looks like  (690,)
# log_probs looks like  690
# rewards looks like  (760,)
# log_probs looks like  760
# rewards looks like  (689,)
# log_probs looks like  689
# rewards looks like  (649,)
# log_probs looks like  649
# rewards looks like  (586,)
# log_probs looks like  586
# rewards looks like  (2500,)
# log_probs looks like  2500
# rewards looks like  (659,)
# log_probs looks like  659
# save_best: 449
# rewards looks like  (4548,)
# log_probs looks like  4548
# rewards looks like  (811,)
# log_probs looks like  811
# save_best: 451
# rewards looks like  (801,)
# log_probs looks like  801
# save_best: 452
# rewards looks like  (5598,)
# log_probs looks like  5598
# rewards looks like  (10000,)
# log_probs looks like  10000
# rewards looks like  (368,)
# log_probs looks like  368
# rewards looks like  (414,)
# log_probs looks like  414
# rewards looks like  (432,)
# log_probs looks like  432
# rewards looks like  (370,)
# log_probs looks like  370
# rewards looks like  (349,)
# log_probs looks like  349
# rewards looks like  (415,)
# log_probs looks like  415
# rewards looks like  (385,)
# log_probs looks like  385
# rewards looks like  (383,)
# log_probs looks like  383
# rewards looks like  (406,)
# log_probs looks like  406
# rewards looks like  (387,)
# log_probs looks like  387
# rewards looks like  (436,)
# log_probs looks like  436
# rewards looks like  (442,)
# log_probs looks like  442
# rewards looks like  (398,)
# log_probs looks like  398
# rewards looks like  (423,)
# log_probs looks like  423
# rewards looks like  (455,)
# log_probs looks like  455
# rewards looks like  (415,)
# log_probs looks like  415
# rewards looks like  (415,)
# log_probs looks like  415
# rewards looks like  (394,)
# log_probs looks like  394
# rewards looks like  (368,)
# log_probs looks like  368
# rewards looks like  (410,)
# log_probs looks like  410
# rewards looks like  (382,)
# log_probs looks like  382
# rewards looks like  (403,)
# log_probs looks like  403
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (444,)
# log_probs looks like  444
# rewards looks like  (384,)
# log_probs looks like  384
# rewards looks like  (363,)
# log_probs looks like  363
# rewards looks like  (398,)
# log_probs looks like  398
# rewards looks like  (419,)
# log_probs looks like  419
# rewards looks like  (405,)
# log_probs looks like  405
# rewards looks like  (1097,)
# log_probs looks like  1097
# rewards looks like  (405,)
# log_probs looks like  405
# rewards looks like  (495,)
# log_probs looks like  495
# rewards looks like  (451,)
# log_probs looks like  451
# rewards looks like  (470,)
# log_probs looks like  470
# rewards looks like  (456,)
# log_probs looks like  456
# rewards looks like  (439,)
# log_probs looks like  439
# rewards looks like  (474,)
# log_probs looks like  474
# rewards looks like  (523,)
# log_probs looks like  523
# rewards looks like  (406,)
# log_probs looks like  406
# rewards looks like  (472,)
# log_probs looks like  472
# rewards looks like  (418,)
# log_probs looks like  418
# rewards looks like  (435,)
# log_probs looks like  435
# rewards looks like  (459,)
# log_probs looks like  459
# rewards looks like  (357,)
# log_probs looks like  357
# rewards looks like  (427,)
# log_probs looks like  427
# rewards looks like  (418,)
# log_probs looks like  418
# rewards looks like  (492,)
# log_probs looks like  492
# rewards looks like  (410,)
# log_probs looks like  410
# rewards looks like  (404,)
# log_probs looks like  404
# rewards looks like  (399,)
# log_probs looks like  399
# rewards looks like  (468,)
# log_probs looks like  468
# rewards looks like  (470,)
# log_probs looks like  470
# rewards looks like  (417,)
# log_probs looks like  417
# rewards looks like  (477,)
# log_probs looks like  477
# rewards looks like  (482,)
# log_probs looks like  482
# rewards looks like  (453,)
# log_probs looks like  453
# rewards looks like  (501,)
# log_probs looks like  501
# rewards looks like  (457,)
# log_probs looks like  457
# rewards looks like  (414,)
# log_probs looks like  414
# rewards looks like  (478,)
# log_probs looks like  478
# rewards looks like  (447,)
# log_probs looks like  447
# rewards looks like  (426,)
# log_probs looks like  426
# rewards looks like  (514,)
# log_probs looks like  514
# rewards looks like  (477,)
# log_probs looks like  477
# rewards looks like  (487,)
# log_probs looks like  487
# rewards looks like  (518,)
# log_probs looks like  518
# rewards looks like  (460,)
# log_probs looks like  460
# rewards looks like  (520,)
# log_probs looks like  520
# rewards looks like  (523,)
# log_probs looks like  523
# rewards looks like  (519,)
# log_probs looks like  519
# rewards looks like  (590,)
# log_probs looks like  590
# rewards looks like  (2438,)
# log_probs looks like  2438
# rewards looks like  (2399,)
# log_probs looks like  2399
# rewards looks like  (543,)
# log_probs looks like  543
# save_best: 528
# rewards looks like  (2427,)
# log_probs looks like  2427
# save_best: 529
# rewards looks like  (470,)
# log_probs looks like  470
# save_best: 530
# rewards looks like  (535,)
# log_probs looks like  535
# rewards looks like  (522,)
# log_probs looks like  522
# save_best: 532
# rewards looks like  (510,)
# log_probs looks like  510
# rewards looks like  (536,)
# log_probs looks like  536
# save_best: 534
# rewards looks like  (2524,)
# log_probs looks like  2524
# rewards looks like  (7906,)
# log_probs looks like  7906
# rewards looks like  (483,)
# log_probs looks like  483
# save_best: 537
# rewards looks like  (575,)
# log_probs looks like  575
# save_best: 538
# rewards looks like  (512,)
# log_probs looks like  512
# rewards looks like  (478,)
# log_probs looks like  478
# rewards looks like  (611,)
# log_probs looks like  611
# rewards looks like  (1164,)
# log_probs looks like  1164
# save_best: 542
# rewards looks like  (2661,)
# log_probs looks like  2661
# save_best: 543
# rewards looks like  (2720,)
# log_probs looks like  2720
# save_best: 544
# rewards looks like  (987,)
# log_probs looks like  987
# save_best: 545
# rewards looks like  (3095,)
# log_probs looks like  3095
# save_best: 546
# rewards looks like  (3754,)
# log_probs looks like  3754
# rewards looks like  (505,)
# log_probs looks like  505
# save_best: 548
# rewards looks like  (554,)
# log_probs looks like  554
# save_best: 549
# rewards looks like  (652,)
# log_probs looks like  652
# save_best: 550
# rewards looks like  (1065,)
# log_probs looks like  1065
# save_best: 551
# rewards looks like  (764,)
# log_probs looks like  764
# save_best: 552
# rewards looks like  (888,)
# log_probs looks like  888
# save_best: 553
# rewards looks like  (1102,)
# log_probs looks like  1102
# save_best: 554
# rewards looks like  (1749,)
# log_probs looks like  1749
# save_best: 555
# rewards looks like  (1361,)
# log_probs looks like  1361
# save_best: 556
# rewards looks like  (9244,)
# log_probs looks like  9244
# rewards looks like  (4386,)
# log_probs looks like  4386
# save_best: 558
# rewards looks like  (6527,)
# log_probs looks like  6527
# save_best: 559
# rewards looks like  (8406,)
# log_probs looks like  8406
# rewards looks like  (466,)
# log_probs looks like  466
# rewards looks like  (459,)
# log_probs looks like  459
# rewards looks like  (551,)
# log_probs looks like  551
# rewards looks like  (476,)
# log_probs looks like  476
# rewards looks like  (445,)
# log_probs looks like  445
# rewards looks like  (371,)
# log_probs looks like  371
# rewards looks like  (464,)
# log_probs looks like  464
# rewards looks like  (500,)
# log_probs looks like  500
# rewards looks like  (511,)
# log_probs looks like  511
# rewards looks like  (484,)
# log_probs looks like  484
# rewards looks like  (461,)
# log_probs looks like  461
# rewards looks like  (500,)
# log_probs looks like  500
# rewards looks like  (502,)
# log_probs looks like  502
# save_best: 573
# rewards looks like  (488,)
# log_probs looks like  488
# save_best: 574
# rewards looks like  (504,)
# log_probs looks like  504
# rewards looks like  (519,)
# log_probs looks like  519
# save_best: 576
# rewards looks like  (529,)
# log_probs looks like  529
# rewards looks like  (492,)
# log_probs looks like  492
# rewards looks like  (501,)
# log_probs looks like  501
# rewards looks like  (549,)
# log_probs looks like  549
# save_best: 580
# rewards looks like  (518,)
# log_probs looks like  518
# save_best: 581
# rewards looks like  (504,)
# log_probs looks like  504
# save_best: 582
# rewards looks like  (558,)
# log_probs looks like  558
# save_best: 583
# rewards looks like  (536,)
# log_probs looks like  536
# save_best: 584
# rewards looks like  (515,)
# log_probs looks like  515
# save_best: 585
# rewards looks like  (448,)
# log_probs looks like  448
# rewards looks like  (489,)
# log_probs looks like  489
# save_best: 587
# rewards looks like  (561,)
# log_probs looks like  561
# rewards looks like  (461,)
# log_probs looks like  461
# rewards looks like  (447,)
# log_probs looks like  447
# rewards looks like  (479,)
# log_probs looks like  479
# rewards looks like  (508,)
# log_probs looks like  508
# rewards looks like  (538,)
# log_probs looks like  538
# rewards looks like  (2421,)
# log_probs looks like  2421
# save_best: 594
# rewards looks like  (619,)
# log_probs looks like  619
# save_best: 595
# rewards looks like  (489,)
# log_probs looks like  489
# rewards looks like  (609,)
# log_probs looks like  609
# rewards looks like  (535,)
# log_probs looks like  535
# rewards looks like  (475,)
# log_probs looks like  475
# save_best: 599
# rewards looks like  (564,)
# log_probs looks like  564
# rewards looks like  (508,)
# log_probs looks like  508
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (549,)
# log_probs looks like  549
# rewards looks like  (519,)
# log_probs looks like  519
# save_best: 604
# rewards looks like  (555,)
# log_probs looks like  555
# save_best: 605
# rewards looks like  (602,)
# log_probs looks like  602
# save_best: 606
# rewards looks like  (2555,)
# log_probs looks like  2555
# save_best: 607
# rewards looks like  (4347,)
# log_probs looks like  4347
# save_best: 608
# rewards looks like  (570,)
# log_probs looks like  570
# rewards looks like  (622,)
# log_probs looks like  622
# rewards looks like  (570,)
# log_probs looks like  570
# rewards looks like  (597,)
# log_probs looks like  597
# rewards looks like  (603,)
# log_probs looks like  603
# rewards looks like  (476,)
# log_probs looks like  476
# rewards looks like  (566,)
# log_probs looks like  566
# save_best: 615
# rewards looks like  (502,)
# log_probs looks like  502
# save_best: 616
# rewards looks like  (510,)
# log_probs looks like  510
# rewards looks like  (561,)
# log_probs looks like  561
# save_best: 618
# rewards looks like  (493,)
# log_probs looks like  493
# rewards looks like  (573,)
# log_probs looks like  573
# save_best: 620
# rewards looks like  (621,)
# log_probs looks like  621
# save_best: 621
# rewards looks like  (544,)
# log_probs looks like  544
# rewards looks like  (681,)
# log_probs looks like  681
# save_best: 623
# rewards looks like  (619,)
# log_probs looks like  619
# save_best: 624
# rewards looks like  (2582,)
# log_probs looks like  2582
# save_best: 625
# rewards looks like  (596,)
# log_probs looks like  596
# save_best: 626
# rewards looks like  (2615,)
# log_probs looks like  2615
# save_best: 627
# rewards looks like  (709,)
# log_probs looks like  709
# rewards looks like  (8155,)
# log_probs looks like  8155
# save_best: 629
# rewards looks like  (6720,)
# log_probs looks like  6720
# save_best: 630
# rewards looks like  (5197,)
# log_probs looks like  5197
# save_best: 631
# rewards looks like  (10000,)
# log_probs looks like  10000
# save_best: 632
# rewards looks like  (2642,)
# log_probs looks like  2642
# save_best: 633
# rewards looks like  (3980,)
# log_probs looks like  3980
# save_best: 634
# rewards looks like  (5166,)
# log_probs looks like  5166
# save_best: 635
# rewards looks like  (647,)
# log_probs looks like  647
# rewards looks like  (724,)
# log_probs looks like  724
# rewards looks like  (3034,)
# log_probs looks like  3034
# save_best: 638
# rewards looks like  (586,)
# log_probs looks like  586
# rewards looks like  (631,)
# log_probs looks like  631
# rewards looks like  (4339,)
# log_probs looks like  4339
# save_best: 641
# rewards looks like  (3744,)
# log_probs looks like  3744
# save_best: 642
# rewards looks like  (9497,)
# log_probs looks like  9497
# rewards looks like  (5263,)
# log_probs looks like  5263
# save_best: 644
# rewards looks like  (2743,)
# log_probs looks like  2743
# save_best: 645
# rewards looks like  (4254,)
# log_probs looks like  4254
# save_best: 646
# rewards looks like  (8201,)
# log_probs looks like  8201
# rewards looks like  (4603,)
# log_probs looks like  4603
# save_best: 648
# rewards looks like  (535,)
# log_probs looks like  535
# rewards looks like  (2214,)
# log_probs looks like  2214
# save_best: 650
# rewards looks like  (787,)
# log_probs looks like  787
# save_best: 651
# rewards looks like  (6679,)
# log_probs looks like  6679
# save_best: 652
# rewards looks like  (2533,)
# log_probs looks like  2533
# rewards looks like  (446,)
# log_probs looks like  446
# rewards looks like  (484,)
# log_probs looks like  484
# rewards looks like  (409,)
# log_probs looks like  409
# rewards looks like  (442,)
# log_probs looks like  442
# rewards looks like  (521,)
# log_probs looks like  521
# rewards looks like  (473,)
# log_probs looks like  473
# rewards looks like  (437,)
# log_probs looks like  437
# rewards looks like  (374,)
# log_probs looks like  374
# rewards looks like  (461,)
# log_probs looks like  461
# rewards looks like  (421,)
# log_probs looks like  421
# rewards looks like  (515,)
# log_probs looks like  515
# rewards looks like  (384,)
# log_probs looks like  384
# rewards looks like  (555,)
# log_probs looks like  555
# rewards looks like  (669,)
# log_probs looks like  669
# rewards looks like  (468,)
# log_probs looks like  468
# rewards looks like  (424,)
# log_probs looks like  424
# rewards looks like  (593,)
# log_probs looks like  593
# rewards looks like  (452,)
# log_probs looks like  452
# rewards looks like  (2604,)
# log_probs looks like  2604
# save_best: 672
# rewards looks like  (428,)
# log_probs looks like  428
# rewards looks like  (546,)
# log_probs looks like  546
# rewards looks like  (503,)
# log_probs looks like  503
# rewards looks like  (580,)
# log_probs looks like  580
# rewards looks like  (638,)
# log_probs looks like  638
# rewards looks like  (606,)
# log_probs looks like  606
# rewards looks like  (1542,)
# log_probs looks like  1542
# save_best: 679
# rewards looks like  (477,)
# log_probs looks like  477
# rewards looks like  (570,)
# log_probs looks like  570
# rewards looks like  (550,)
# log_probs looks like  550
# rewards looks like  (486,)
# log_probs looks like  486
# rewards looks like  (405,)
# log_probs looks like  405
# rewards looks like  (620,)
# log_probs looks like  620
# save_best: 685
# rewards looks like  (1082,)
# log_probs looks like  1082
# save_best: 686
# rewards looks like  (1003,)
# log_probs looks like  1003
# save_best: 687
# rewards looks like  (975,)
# log_probs looks like  975
# save_best: 688
# rewards looks like  (539,)
# log_probs looks like  539
# rewards looks like  (646,)
# log_probs looks like  646
# save_best: 690
# rewards looks like  (784,)
# log_probs looks like  784
# rewards looks like  (703,)
# log_probs looks like  703
# rewards looks like  (625,)
# log_probs looks like  625
# rewards looks like  (652,)
# log_probs looks like  652
# rewards looks like  (796,)
# log_probs looks like  796
# save_best: 695
# rewards looks like  (2816,)
# log_probs looks like  2816
# save_best: 696
# rewards looks like  (1380,)
# log_probs looks like  1380
# rewards looks like  (569,)
# log_probs looks like  569
# rewards looks like  (724,)
# log_probs looks like  724
# rewards looks like  (1100,)
# log_probs looks like  1100
# save_best: 700
# rewards looks like  (532,)
# log_probs looks like  532
# rewards looks like  (480,)
# log_probs looks like  480
# rewards looks like  (778,)
# log_probs looks like  778
# rewards looks like  (557,)
# log_probs looks like  557
# rewards looks like  (606,)
# log_probs looks like  606
# rewards looks like  (661,)
# log_probs looks like  661
# rewards looks like  (651,)
# log_probs looks like  651
# save_best: 707
# rewards looks like  (681,)
# log_probs looks like  681
# save_best: 708
# rewards looks like  (585,)
# log_probs looks like  585
# rewards looks like  (592,)
# log_probs looks like  592
# rewards looks like  (544,)
# log_probs looks like  544
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (494,)
# log_probs looks like  494
# rewards looks like  (468,)
# log_probs looks like  468
# save_best: 714
# rewards looks like  (406,)
# log_probs looks like  406
# rewards looks like  (476,)
# log_probs looks like  476
# rewards looks like  (558,)
# log_probs looks like  558
# rewards looks like  (450,)
# log_probs looks like  450
# rewards looks like  (463,)
# log_probs looks like  463
# rewards looks like  (466,)
# log_probs looks like  466
# rewards looks like  (490,)
# log_probs looks like  490
# rewards looks like  (466,)
# log_probs looks like  466
# rewards looks like  (480,)
# log_probs looks like  480
# rewards looks like  (471,)
# log_probs looks like  471
# save_best: 724
# rewards looks like  (530,)
# log_probs looks like  530
# rewards looks like  (472,)
# log_probs looks like  472
# rewards looks like  (478,)
# log_probs looks like  478
# save_best: 727
# rewards looks like  (472,)
# log_probs looks like  472
# rewards looks like  (397,)
# log_probs looks like  397
# rewards looks like  (486,)
# log_probs looks like  486
# save_best: 730
# rewards looks like  (431,)
# log_probs looks like  431
# rewards looks like  (397,)
# log_probs looks like  397
# save_best: 732
# rewards looks like  (431,)
# log_probs looks like  431
# rewards looks like  (358,)
# log_probs looks like  358
# rewards looks like  (441,)
# log_probs looks like  441
# rewards looks like  (435,)
# log_probs looks like  435
# rewards looks like  (460,)
# log_probs looks like  460
# rewards looks like  (443,)
# log_probs looks like  443
# rewards looks like  (377,)
# log_probs looks like  377
# rewards looks like  (434,)
# log_probs looks like  434
# rewards looks like  (432,)
# log_probs looks like  432
# rewards looks like  (374,)
# log_probs looks like  374
# rewards looks like  (383,)
# log_probs looks like  383
# rewards looks like  (480,)
# log_probs looks like  480
# rewards looks like  (419,)
# log_probs looks like  419
# rewards looks like  (355,)
# log_probs looks like  355
# rewards looks like  (393,)
# log_probs looks like  393
# rewards looks like  (374,)
# log_probs looks like  374
# rewards looks like  (354,)
# log_probs looks like  354
# rewards looks like  (370,)
# log_probs looks like  370
# rewards looks like  (432,)
# log_probs looks like  432
# rewards looks like  (346,)
# log_probs looks like  346
# rewards looks like  (406,)
# log_probs looks like  406
# rewards looks like  (343,)
# log_probs looks like  343
# rewards looks like  (377,)
# log_probs looks like  377
# rewards looks like  (408,)
# log_probs looks like  408
# rewards looks like  (421,)
# log_probs looks like  421
# rewards looks like  (410,)
# log_probs looks like  410
# rewards looks like  (367,)
# log_probs looks like  367
# rewards looks like  (462,)
# log_probs looks like  462
# rewards looks like  (448,)
# log_probs looks like  448
# rewards looks like  (436,)
# log_probs looks like  436
# rewards looks like  (447,)
# log_probs looks like  447
# rewards looks like  (396,)
# log_probs looks like  396
# rewards looks like  (463,)
# log_probs looks like  463
# rewards looks like  (438,)
# log_probs looks like  438
# rewards looks like  (489,)
# log_probs looks like  489
# rewards looks like  (423,)
# log_probs looks like  423
# rewards looks like  (425,)
# log_probs looks like  425
# rewards looks like  (431,)
# log_probs looks like  431
# rewards looks like  (367,)
# log_probs looks like  367
# rewards looks like  (436,)
# log_probs looks like  436
# rewards looks like  (459,)
# log_probs looks like  459
# save_best: 773
# rewards looks like  (425,)
# log_probs looks like  425
# rewards looks like  (488,)
# log_probs looks like  488
# rewards looks like  (430,)
# log_probs looks like  430
# rewards looks like  (367,)
# log_probs looks like  367
# rewards looks like  (400,)
# log_probs looks like  400
# rewards looks like  (437,)
# log_probs looks like  437
# rewards looks like  (428,)
# log_probs looks like  428
# rewards looks like  (446,)
# log_probs looks like  446
# rewards looks like  (463,)
# log_probs looks like  463
# rewards looks like  (442,)
# log_probs looks like  442
# rewards looks like  (421,)
# log_probs looks like  421
# rewards looks like  (393,)
# log_probs looks like  393
# rewards looks like  (385,)
# log_probs looks like  385
# rewards looks like  (403,)
# log_probs looks like  403
# rewards looks like  (408,)
# log_probs looks like  408
# rewards looks like  (558,)
# log_probs looks like  558
# save_best: 789
# rewards looks like  (496,)
# log_probs looks like  496
# rewards looks like  (406,)
# log_probs looks like  406
# rewards looks like  (409,)
# log_probs looks like  409
# rewards looks like  (458,)
# log_probs looks like  458
# save_best: 793
# rewards looks like  (546,)
# log_probs looks like  546
# save_best: 794
# rewards looks like  (525,)
# log_probs looks like  525
# save_best: 795
# rewards looks like  (557,)
# log_probs looks like  557
# save_best: 796
# rewards looks like  (535,)
# log_probs looks like  535
# save_best: 797
# rewards looks like  (573,)
# log_probs looks like  573
# rewards looks like  (530,)
# log_probs looks like  530
# save_best: 799
# rewards looks like  (549,)
# log_probs looks like  549
# save_best: 800
# rewards looks like  (459,)
# log_probs looks like  459
# save_best: 801
# rewards looks like  (538,)
# log_probs looks like  538
# save_best: 802
# rewards looks like  (580,)
# log_probs looks like  580
# save_best: 803
# rewards looks like  (620,)
# log_probs looks like  620
# save_best: 804
# rewards looks like  (553,)
# log_probs looks like  553
# rewards looks like  (1031,)
# log_probs looks like  1031
# save_best: 806
# rewards looks like  (537,)
# log_probs looks like  537
# rewards looks like  (569,)
# log_probs looks like  569
# rewards looks like  (4463,)
# log_probs looks like  4463
# save_best: 809
# rewards looks like  (1184,)
# log_probs looks like  1184
# save_best: 810
# rewards looks like  (584,)
# log_probs looks like  584
# rewards looks like  (1677,)
# log_probs looks like  1677
# rewards looks like  (820,)
# log_probs looks like  820
# rewards looks like  (505,)
# log_probs looks like  505
# rewards looks like  (635,)
# log_probs looks like  635
# rewards looks like  (378,)
# log_probs looks like  378
# rewards looks like  (481,)
# log_probs looks like  481
# rewards looks like  (528,)
# log_probs looks like  528
# rewards looks like  (426,)
# log_probs looks like  426
# rewards looks like  (530,)
# log_probs looks like  530
# rewards looks like  (633,)
# log_probs looks like  633
# rewards looks like  (1502,)
# log_probs looks like  1502
# rewards looks like  (553,)
# log_probs looks like  553
# rewards looks like  (726,)
# log_probs looks like  726
# save_best: 824
# rewards looks like  (2672,)
# log_probs looks like  2672
# save_best: 825
# rewards looks like  (2847,)
# log_probs looks like  2847
# save_best: 826
# rewards looks like  (3351,)
# log_probs looks like  3351
# save_best: 827
# rewards looks like  (2759,)
# log_probs looks like  2759
# save_best: 828
# rewards looks like  (4439,)
# log_probs looks like  4439
# save_best: 829
# rewards looks like  (662,)
# log_probs looks like  662
# rewards looks like  (512,)
# log_probs looks like  512
# rewards looks like  (1787,)
# log_probs looks like  1787
# rewards looks like  (533,)
# log_probs looks like  533
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 26
#      22 total_step += 1
#      24 state = next_state
# ---> 26 prg_bar.set_postfix({"current_step":total_step})
#      27 if done or total_step == 2000:
#      28     seq_rewards = np.array(seq_rewards)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\tqdm\std.py:1445, in tqdm.set_postfix(self, ordered_dict, refresh, **kwargs)
#    1442 self.postfix = ', '.join(key + '=' + postfix[key].strip()
#    1443                          for key in postfix.keys())
#    1444 if refresh:
# -> 1445     self.refresh()
#
# File ~\Desktop\machine-learning\env\lib\site-packages\tqdm\std.py:1361, in tqdm.refresh(self, nolock, lock_args)
#    1359     else:
#    1360         self._lock.acquire()
# -> 1361 self.display()
#    1362 if not nolock:
#    1363     self._lock.release()
#
# File ~\Desktop\machine-learning\env\lib\site-packages\tqdm\notebook.py:180, in tqdm_notebook.display(self, msg, pos, close, bar_style, check_delay)
#     178     # never clear the bar (signal: msg='')
#     179     if right:
# --> 180         rtext.value = right
#     182 # Change bar style
#     183 if bar_style:
#     184     # Hack-ish way to avoid the danger bar_style being overridden by
#     185     # success because the bar gets closed after the error...
#
# File ~\Desktop\machine-learning\env\lib\site-packages\traitlets\traitlets.py:729, in TraitType.__set__(self, obj, value)
#     727     raise TraitError('The "%s" trait is read-only.' % self.name)
#     728 else:
# --> 729     self.set(obj, value)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\traitlets\traitlets.py:718, in TraitType.set(self, obj, value)
#     714     silent = False
#     715 if silent is not True:
#     716     # we explicitly compare silent to True just in case the equality
#     717     # comparison above returns something other than True/False
# --> 718     obj._notify_trait(self.name, old_value, new_value)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\traitlets\traitlets.py:1501, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1500 def _notify_trait(self, name, old_value, new_value):
# -> 1501     self.notify_change(
#    1502         Bunch(
#    1503             name=name,
#    1504             old=old_value,
#    1505             new=new_value,
#    1506             owner=self,
#    1507             type="change",
#    1508         )
#    1509     )
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipywidgets\widgets\widget.py:605, in Widget.notify_change(self, change)
#     601 if self.comm is not None and self.comm.kernel is not None:
#     602     # Make sure this isn't information that the front-end just sent us.
#     603     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604         # Send new state to front-end
# --> 605         self.send_state(key=name)
#     606 super(Widget, self).notify_change(change)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipywidgets\widgets\widget.py:489, in Widget.send_state(self, key)
#     487 state, buffer_paths, buffers = _remove_buffers(state)
#     488 msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 489 self._send(msg, buffers=buffers)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipywidgets\widgets\widget.py:737, in Widget._send(self, msg, buffers)
#     735 """Sends a message to the model in the front-end."""
#     736 if self.comm is not None and self.comm.kernel is not None:
# --> 737     self.comm.send(data=msg, buffers=buffers)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipykernel\comm\comm.py:137, in Comm.send(self, data, metadata, buffers)
#     135 def send(self, data=None, metadata=None, buffers=None):
#     136     """Send a message to the frontend-side version of this comm"""
# --> 137     self._publish_msg(
#     138         "comm_msg",
#     139         data=data,
#     140         metadata=metadata,
#     141         buffers=buffers,
#     142     )
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipykernel\comm\comm.py:71, in Comm._publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      69 metadata = {} if metadata is None else metadata
#      70 content = json_clean(dict(data=data, comm_id=self.comm_id, **keys))
# ---> 71 self.kernel.session.send(
#      72     self.kernel.iopub_socket,
#      73     msg_type,
#      74     content,
#      75     metadata=json_clean(metadata),
#      76     parent=self.kernel.get_parent("shell"),
#      77     ident=self.topic,
#      78     buffers=buffers,
#      79 )
#
# File ~\Desktop\machine-learning\env\lib\site-packages\jupyter_client\session.py:859, in Session.send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     856 elif stream:
#     857     # use dummy tracker, which will be done immediately
#     858     tracker = DONE
# --> 859     stream.send_multipart(to_send, copy=copy)
#     861 if self.debug:
#     862     pprint.pprint(msg)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipykernel\iostream.py:286, in BackgroundSocket.send_multipart(self, *args, **kwargs)
#     284 """Schedule send in IO thread"""
#     285 assert self.io_thread is not None
# --> 286 return self.io_thread.send_multipart(*args, **kwargs)
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipykernel\iostream.py:219, in IOPubThread.send_multipart(self, *args, **kwargs)
#     214 def send_multipart(self, *args, **kwargs):
#     215     """send_multipart schedules actual zmq send in my thread.
#     216
#     217     If my thread isn't running (e.g. forked process), send immediately.
#     218     """
# --> 219     self.schedule(lambda: self._really_send(*args, **kwargs))
#
# File ~\Desktop\machine-learning\env\lib\site-packages\ipykernel\iostream.py:210, in IOPubThread.schedule(self, f)
#     208     self._events.append(f)
#     209     # wake event thread (message content is ignored)
# --> 210     self._event_pipe.send(b"")
#     211 else:
#     212     f()
#
# File ~\Desktop\machine-learning\env\lib\site-packages\zmq\sugar\socket.py:618, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     611         data = zmq.Frame(
#     612             data,
#     613             track=track,
#     614             copy=copy or None,
#     615             copy_threshold=self.copy_threshold,
#     616         )
#     617     data.group = group
# --> 618 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File ~\Desktop\machine-learning\env\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import time
import math
end = time.time()
plt.plot(avg_total_rewards)
plt.title("Total Rewards")
plt.show()

# %%
plt.plot(avg_final_rewards)
plt.title("Final Rewards")
plt.show()

# %%
list = [float(i) for i in agent.loss_a]
plt.subplot(2, 1, 1)
plt.plot(list,"r")
plt.title("action_loss")
plt.show()
plt.subplot(2, 1, 2)
list = [float(i) for i in agent.loss_r]
plt.plot(list,"b")
plt.title("reward_loss")
plt.show()

# %%
fix(seed)
agent.network.load_state_dict(torch.load("best_net.bin"))
agent.network.eval()  # 測試前先將 network 切換為 evaluation 模式
NUM_OF_TEST = 20 # Do not revise it !!!!!
test_total_reward = []
action_list = []
for i in range(NUM_OF_TEST):
    actions = []
    state = env.reset()[0]

    total_reward = 0

    done = False
    while not done:
        action, _, _ = agent.sample(state)
        actions.append(action)
        state, reward, done, _, _ = env.step(action)

        total_reward += reward

        #img.set_data(env.render(mode='rgb_array'))
        #display.display(plt.gcf())
        #display.clear_output(wait=True)
    print(total_reward)
    test_total_reward.append(total_reward)

    action_list.append(actions) #儲存你測試的結果
    print("length of actions is ", len(actions))

# %%
print(f"Your final reward is : %.2f"%np.mean(test_total_reward))

# %%
print("Action list looks like ", action_list)
print("Action list's shape looks like ", np.shape(action_list))

# %%
distribution = {}
for actions in action_list:
  for action in actions:
    if action not in distribution.keys():
      distribution[action] = 1
    else:
      distribution[action] += 1
print(distribution)

# %%
PATH = "Action_List_test.npy" # 可以改成你想取的名字或路徑
np.save(PATH ,np.array(action_list))
